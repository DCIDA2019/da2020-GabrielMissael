# %%
import pandas as pd
import numpy as np

#Cargamos los archivos .csv a un DataFrame
tempMax = pd.read_csv("temperatura_maxima.csv", encoding = 'Latin-1')
tempMid = pd.read_csv("temperatura_media.csv", encoding = 'Latin-1')
tempMin = pd.read_csv("temperatura_minima.csv", encoding = 'Latin-1')
lluvia = pd.read_csv("lluvia.csv", encoding = 'Latin-1')

# %%
temperatura = pd.merge(tempMax.set_index(['Edo']).sort_index(),
                       pd.merge(tempMin.set_index(['Edo']).sort_index(), 
                                tempMid.set_index(['Edo']).sort_index(),
                                how='left'), how='left')

# %%
temperatura
# Out:
#         Lon    Lat  Clave                  Est       Tmax      Tmin       Tmed
# 0   -102.68  22.00  CDRAG     La Codorniz Ags.  24.516129  7.112903  15.814516
# 1   -102.79  21.81  MNLAG      Media Luna Ags.  25.516129  3.483871  14.500000
# 2   -102.37  21.78  NGRAG      El Niagara Ags.  24.306452  3.741935  14.024194
# 3   -102.31  21.90  AGSAG  Aguascalientes Ags.  23.467742  6.403226  14.935484
# 4   -102.00  21.90  CNSAG       Los Conos Ags.  23.419355  3.790323  13.604839
# ..      ...    ...    ...                  ...        ...       ...        ...
# 717 -103.51  24.29  SGOZC        Santiago Zac.  16.387097  3.758065  10.072581
# 718 -103.65  23.47  76471           SOMBRERETE  21.545161  4.903226  13.224194
# 719 -102.57  22.78  76525            ZACATECAS  15.932258  7.441935  11.687097
# 720 -102.51  22.75  GPEZC       Guadalupe Zac.  20.774194  5.167742  12.970968
# 721 -103.35  21.65  EXCZC   Miguel Alemán Zac.  24.709677  3.290323  14.000000
#
# [722 rows x 7 columns]

# %%
tempMid.set_index(['Edo']).sort_index()
# Out:
#         Lon    Lat     Clave                                  Est       Tmed
# Edo
# AGS -102.30  22.36     CSOAG                           Cosío Ags.   9.435484
# AGS -102.44  22.24     PTRAG             Derivadora Pabellón Ags.  13.572581
# AGS -102.79  21.81     MNLAG                      Media Luna Ags.  14.500000
# AGS -102.71  21.85  CALVILLO                   Calvillo Ags. SMN*  15.198387
# AGS -102.29  21.85     OBSAG  Observatorio de Aguascalientes Ags.  14.896774
# ..      ...    ...       ...                                  ...        ...
# ZAC -103.65  23.47     76471                           SOMBRERETE  13.224194
# ZAC -102.57  22.78     76525                            ZACATECAS  11.687097
# ZAC -103.51  24.29     SGOZC                        Santiago Zac.  10.072581
# ZAC -101.72  22.35     VHGZC                   Villa Hidalgo Zac.  10.838710
# ZAC -103.03  23.82     RGRZC                      Río Grande Zac.  11.637097
#
# [635 rows x 5 columns]
