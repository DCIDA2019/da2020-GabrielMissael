# %%
import numpy as np
import matplotlib.pyplot as plt

def funcion(i):
    return (5000*(((i+1)**6-1)/i))

# %%
x = np.linspace(0.0612,0.0615,10000)

# %%
y = [funcion(dato) for dato in x]

# %%
plt.plot(x, y)
plt.plot(x, [35000 for x in x])
plt.grid()
