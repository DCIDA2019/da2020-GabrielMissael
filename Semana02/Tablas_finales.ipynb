# %%
import pandas as pd
import numpy as np

#Cargamos los archivos .csv a un DataFrame
tempMax = pd.read_csv("temperatura_maxima.csv", encoding = 'Latin-1')
tempMid = pd.read_csv("temperatura_media.csv", encoding = 'Latin-1')
tempMin = pd.read_csv("temperatura_minima.csv", encoding = 'Latin-1')
lluvia18 = pd.read_csv("lluvia2018-2.csv", encoding = 'Latin-1')
lluvia19 = pd.read_csv("lluvia2019-2.csv", encoding = 'Latin-1')
lluvia20 = pd.read_csv("lluvia2020-2.csv", encoding = 'Latin-1')

# %%
#Hacemos merge de las tres tablas. Usamos how = left para evitar que quite filas 
#donde falten entradas y mejor los llene con un NaN
temperatura = pd.merge(tempMax, pd.merge(tempMin, tempMid))
ds
#Creamos un indice multiple, de estado y localidad. Usamos sort.index() para ordenar 
#los estados por orden alfabetico
temperatura = temperatura.set_index(['Edo', 'Est']).sort_index(level = 0)
aux_temp = temperatura

#Cambiamos los nombres de las columnas del indice multiple
temperatura = temperatura.rename_axis(['Estado', 'Localidad'])

#Previsualizamos la tabla
display(temperatura)
# Out:
#                                       Lon    Lat     Clave       Tmax  \
# Estado Localidad
# AGS    Aguascalientes Ags.        -102.31  21.90     AGSAG  23.467742
#        Calvillo Ags. SMN*         -102.71  21.85  CALVILLO  26.522581
#        Cincuenta Aniversario Ags. -102.47  22.19     ANVAG  22.722581
#        Cosío Ags.                 -102.30  22.36     CSOAG  18.080645
#        Derivadora Pabellón Ags.   -102.44  22.24     PTRAG  22.080645
# ...                                   ...    ...       ...        ...
# ZAC    Sombrerete Zac.            -103.64  23.64     SOMZC  22.129032
#        Villa Hidalgo Zac.         -101.72  22.35     VHGZC  19.806452
#        ZACATECAS                  -102.57  22.78     76525  15.932258
#        Zacatecas Zac.             -102.58  22.76     ZACZC  19.870968
#        Zacatecas Zac. SMN*        -102.51  22.75     ZA2ZC  20.361290
#
#                                        Tmin       Tmed
# Estado Localidad
# AGS    Aguascalientes Ags.         6.403226  14.935484
#        Calvillo Ags. SMN*          3.874194  15.198387
#        Cincuenta Aniversario Ags.  5.422581  14.072581
#        Cosío Ags.                  0.790323   9.435484
#        Derivadora Pabellón Ags.    5.064516  13.572581
# ...                                     ...        ...
# ZAC    Sombrerete Zac.             5.012903  13.570968
#        Villa Hidalgo Zac.          1.870968  10.838710
#        ZACATECAS                   7.441935  11.687097
#        Zacatecas Zac.              7.693548  13.782258
#        Zacatecas Zac. SMN*         5.445161  12.903226
#
# [635 rows x 6 columns]

# %%
#Renombramos nombres de columnas para que coincidan y hacer el merge
#Pudimos haber indicado que son lo mismo sin cambiar el nombrem pero
#lo hacemos por si las tenemos que manipular de nuevo
lluvia19 = lluvia19.rename(columns={"EDO":"Edo"})
lluvia19 = lluvia19.rename(columns={"JUN":"2019"})
lluvia19 = lluvia19.rename(columns={"CLAVE_SIH":"CLAVE"})

lluvia18 = lluvia18.rename(columns={"CLAVE_SIH":"CLAVE"})
lluvia18 = lluvia18.rename(columns={"ESTACION":"NOMBRE"})
lluvia18 = lluvia18.rename(columns={"JUN":"2018"})
lluvia18 = lluvia18.rename(columns={"EDO":"Edo"})

lluvia20 = lluvia20.rename(columns={"EDO":"Edo"})
lluvia20 = lluvia20.rename(columns={"ene-20":"2020"})
lluvia20 = lluvia20.rename(columns={"ESTACION":"NOMBRE"})

# %%
#Repetimos lo mismo que con la tabla de temperaturas
lluvias = pd.merge(lluvia20, pd.merge(lluvia18, lluvia19))
lluvias = lluvias.rename(columns={"Edo":"Estado", "CLAVE":"Clave", "NOMBRE":"Localidad", "LON":"Lon", "LAT": "Lat"})
aux_lluvias = lluvias
aux_lluvias = lluvias.drop(columns=["Lon", "Lat"])
lluvias = lluvias.set_index(['Estado', 'Localidad']).sort_index()
lluvias
# Out:
#                                          Lon        Lat     Clave  2020  \
# Estado Localidad
# AGS    Aguascalientes, Ags.      -102.309722  21.895000     AGSAG  31.1
#        Calvillo, Ags. SMN*       -102.712222  21.849167  CALVILLO  39.4
#        Cosío, Ags.               -102.296667  22.362778     CSOAG  39.5
#        Derivadora Pabellón, Ags. -102.437500  22.235000     PTRAG  31.8
#        El Niagara, Ags.          -102.371667  21.780000     NGRAG  29.4
# ...                                      ...        ...       ...   ...
# ZAC    Santiago, Zac.            -103.506111  24.288611     SGOZC  26.9
#        Sombrerete, Zac.          -103.636667  23.638889     SOMZC  13.7
#        Tlaltenango, Zac.         -103.309444  21.773611     TLLZC  25.5
#        Villa Hidalgo, Zac.       -101.715833  22.347500     VHGZC  35.3
#        Zacatecas, Zac.           -102.576667  22.761389     ZACZC  34.1
#
#                                     2018    2019
# Estado Localidad
# AGS    Aguascalientes, Ags.       112.50   44.19
#        Calvillo, Ags. SMN*        201.50  101.27
#        Cosío, Ags.                208.04   17.28
#        Derivadora Pabellón, Ags.  279.83   46.85
#        El Niagara, Ags.           260.01   19.96
# ...                                  ...     ...
# ZAC    Santiago, Zac.              78.00   53.12
#        Sombrerete, Zac.            77.90   25.20
#        Tlaltenango, Zac.          218.73   65.43
#        Villa Hidalgo, Zac.        220.90   49.30
#        Zacatecas, Zac.            236.00   44.32
#
# [1001 rows x 6 columns]

# %%
#Guardamos la tabla generada
lluvias.to_csv("LLUVIAS-2018-2020.csv")
temperatura.to_csv("TEMPERATURAS2019.csv")

# %%
temperaturas_lluvias = pd.merge(aux_lluvias, aux_temp, on="Clave")
temperaturas_lluvias = temperaturas_lluvias.set_index(['Estado', 'Localidad']).sort_index()
temperaturas_lluvias = temperaturas_lluvias[['Clave', 'Lon', 'Lat', '2018', 
                                             '2019', '2020', 'Tmax','Tmin','Tmed']]
temperaturas_lluvias
# Out:
#                                                        Clave     Lon    Lat  \
# Estado Localidad
# AGS    Aguascalientes, Ags.                            AGSAG -102.31  21.90
#        Calvillo, Ags. SMN*                          CALVILLO -102.71  21.85
#        Cosío, Ags.                                     CSOAG -102.30  22.36
#        Derivadora Pabellón, Ags.                       PTRAG -102.44  22.24
#        El Niagara, Ags.                                NGRAG -102.37  21.78
# ...                                                      ...     ...    ...
# ZAC    Santa Teresa (Independencia Nacional), Zac.     STEZC -103.50  22.33
#        Santiago, Zac.                                  SGOZC -103.51  24.29
#        Sombrerete, Zac.                                SOMZC -103.64  23.64
#        Villa Hidalgo, Zac.                             VHGZC -101.72  22.35
#        Zacatecas, Zac.                                 ZACZC -102.58  22.76
#
#                                                       2018    2019  2020  \
# Estado Localidad
# AGS    Aguascalientes, Ags.                         112.50   44.19  31.1
#        Calvillo, Ags. SMN*                          201.50  101.27  39.4
#        Cosío, Ags.                                  208.04   17.28  39.5
#        Derivadora Pabellón, Ags.                    279.83   46.85  31.8
#        El Niagara, Ags.                             260.01   19.96  29.4
# ...                                                    ...     ...   ...
# ZAC    Santa Teresa (Independencia Nacional), Zac.  176.10   46.20  49.4
#        Santiago, Zac.                                78.00   53.12  26.9
#        Sombrerete, Zac.                              77.90   25.20  13.7
#        Villa Hidalgo, Zac.                          220.90   49.30  35.3
#        Zacatecas, Zac.                              236.00   44.32  34.1
#
#                                                          Tmax      Tmin  \
# Estado Localidad
# AGS    Aguascalientes, Ags.                         23.467742  6.403226
#        Calvillo, Ags. SMN*                          26.522581  3.874194
#        Cosío, Ags.                                  18.080645  0.790323
#        Derivadora Pabellón, Ags.                    22.080645  5.064516
#        El Niagara, Ags.                             24.306452  3.741935
# ...                                                       ...       ...
# ZAC    Santa Teresa (Independencia Nacional), Zac.  22.225806  5.112903
#        Santiago, Zac.                               16.387097  3.758065
#        Sombrerete, Zac.                             22.129032  5.012903
#        Villa Hidalgo, Zac.                          19.806452  1.870968
#        Zacatecas, Zac.                              19.870968  7.693548
#
#                                                          Tmed
# Estado Localidad
# AGS    Aguascalientes, Ags.                         14.935484
#        Calvillo, Ags. SMN*                          15.198387
#        Cosío, Ags.                                   9.435484
#        Derivadora Pabellón, Ags.                    13.572581
#        El Niagara, Ags.                             14.024194
# ...                                                       ...
# ZAC    Santa Teresa (Independencia Nacional), Zac.  13.669355
#        Santiago, Zac.                               10.072581
#        Sombrerete, Zac.                             13.570968
#        Villa Hidalgo, Zac.                          10.838710
#        Zacatecas, Zac.                              13.782258
#
# [464 rows x 9 columns]

# %%
temperaturas_lluvias.to_csv("TEMPERATURAS_LLUVIAS.csv")
